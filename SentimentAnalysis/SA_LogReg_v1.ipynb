# %% [markdown]
# * Sentiment analysis
# * Baseline: Logistic Regression
# * IMDB dataset

# %% [markdown]
# * From v0.
# * The main change is using ngram of 4 instead of 1

# %% [markdown]
# # Import libraries

# %%
# for reloading any changed module
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
import torch

# %%
from pathlib import Path
import sys
import os

# %%
from torch.utils.data import DataLoader

# %%
Path.cwd().parent.parent.parent
# Out:
# PosixPath('/media/skesava/D/Training/MachineLearning')

# %%
data_directory = Path.cwd().parent.parent.parent.joinpath("ML datasets/IMDB_SentimentAnalysis_TextData/aclImdb")

# %%
if not data_directory.exists():
    raise FileNotFoundError()

# %%
processed_data_directory = data_directory.joinpath("processed_data")

# %%
processed_data_directory.exists()
# Out:
# True

# %%
df_train = pd.read_csv(processed_data_directory.joinpath("train.csv"))
df_train.head(5)
# Out:
#                                                 text  label
# 0  Robert Duvall is a direct descendent of Confed...      1
# 1  The Railway Children, at least this 1970 movie...      1
# 2  Anatomie was a German made Movie and subtitled...      0
# 3  This film makes Clooney. All his films combine...      1
# 4  This is easily the best cinematic version of W...      1

# %%
df_train.tail(5)
# Out:
#                                                     text  label
# 34995  This movie is well done. It really attempts to...      1
# 34996  Ever wonder where the ideas for romance novels...      1
# 34997  How truly friendly, charming and cordial is th...      1
# 34998  Very good 1939 film where John Garfield plays ...      1
# 34999  I couldn't disagree more with those who says t...      1

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35000 entries, 0 to 34999
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   text    35000 non-null  object
#  1   label   35000 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 547.0+ KB

# %%
df_test = pd.read_csv(processed_data_directory.joinpath("test.csv"))
df_test.head(5)
# Out:
#                                                 text  label
# 0  I have to say, when "Pushing Daisies" came out...      1
# 1  Bah. Another tired, desultory reworking of an ...      0
# 2  It's a shame that Asterix and his buddy Obelix...      1
# 3  this is the worst movie ive ever seen. And i h...      0
# 4  The comments for Commune make it sound like a ...      0

# %%
df_val = pd.read_csv(processed_data_directory.joinpath("val.csv"))
df_val.head(5)
# Out:
#                                                 text  label
# 0  This is one of the funniest movies I've ever s...      1
# 1  One of my favorite westerns and one of John Fo...      1
# 2  I felt I had to add a comment after seeing the...      0
# 3  Not to be mistaken as the highly touted Samuel...      0
# 4  I watched the entire movie recognizing the par...      0

# %% [markdown]
# # Bag of Words model

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
max_input_features = 10000

# %%
cv = CountVectorizer(encoding='utf-8', 
                     lowercase=True, 
                     stop_words='english',
                     max_features=max_input_features,
                     ngram_range=(4,4)                     
                    )

# %% [markdown]
# ### FIT

# %%
cv.fit(df_train['text'])
# Out:
# CountVectorizer(max_features=10000, ngram_range=(4, 4), stop_words='english')

# %%
cv.vocabulary_
# Out:
# {'important story br br': 5923,
#  'happy ending br br': 5663,
#  've seen ve seen': 9464,
#  'br br far know': 1411,
#  'br br actors great': 912,
#  'entire movie br br': 4741,
#  'br br given film': 1669,
#  'br br downside movie': 1294,
#  'br br opening scene': 2470,
#  'different br br movie': 4346,
#  'br br movie does': 2277,
#  'just don make movies': 6108,
#  'don make movies like': 4490,
#  'make movies like anymore': 6784,
#  'br br fact actually': 1371,
#  'love smell napalm morning': 6675,
#  'br br lot people': 2133,
#  'br br movie based': 2249,
#  'possible way br br': 7854,
#  'br br true classic': 3211,
#  'br br rating 10': 2676,
#  'br br ll rooting': 2108,
#  'br br great film': 1741,
#  'br br film funny': 1503,
#  'watching old black white': 9690,
#  'br br bad things': 992,
#  'br br ve seen': 3255,
#  've seen half dozen': 9435,
#  'seen half dozen times': 8507,
#  'half dozen times time': 5640,
#  'br br does film': 1244,
#  'br br movie funny': 2297,
#  'film extremely low budget': 5085,
#  'br br probably best': 2634,
#  'nightmare elm street series': 7491,
#  'br br performances really': 2550,
#  'br br don fooled': 1261,
#  'br br recommended fans': 2762,
#  'fast times ridgemont high': 4880,
#  'really bad movie just': 8062,
#  'br br slow paced': 2952,
#  'don think ve seen': 4513,
#  'think ve seen episode': 9111,
#  'episode wrap like say': 4751,
#  'wrap like say ll': 9907,
#  'like say ll remember': 6454,
#  'say ll remember memory': 8363,
#  'll remember memory forever': 6542,
#  've seen episode conclusion': 9431,
#  'hope catch day goes': 5814,
#  'catch day goes air': 3861,
#  'day goes air good': 4192,
#  'big time br br': 689,
#  'human br br movie': 5876,
#  'john turturro tim blake': 6060,
#  'turturro tim blake nelson': 9333,
#  've seen lot worse': 9446,
#  'johnny cammareri danny aiello': 6062,
#  'wanted like really did': 9557,
#  'love film br br': 6669,
#  'br br going try': 1682,
#  'br br favor don': 1418,
#  'worst movies ve seen': 9882,
#  'horror movie br br': 5834,
#  'br br rate 10': 2667,
#  'br br wonderful film': 3352,
#  'won academy award best': 9787,
#  'academy award best picture': 136,
#  'tourist trap genuinely spooky': 9261,
#  'low budget horror film': 6693,
#  'contains extremely strange atmosphere': 4079,
#  'schmoeller returned make genre': 8418,
#  'tourist trap definitely best': 9260,
#  'best horror film want': 601,
#  'br br rated pg': 2672,
#  'br br eric stoltz': 1351,
#  'life br br really': 6378,
#  'br br really film': 2709,
#  'bette davis joan crawford': 636,
#  'movie seen entire life': 7298,
#  'bar br br movie': 540,
#  'br br movie complete': 2265,
#  'br br like movies': 2066,
#  'movies like bad movies': 7386,
#  'br br great movie': 1751,
#  'br br makes film': 2182,
#  'br br worth watching': 3374,
#  'film br br dialogue': 4959,
#  'credits roll br br': 4131,
#  'br br didn like': 1219,
#  'lock stock smoking barrels': 6558,
#  'br br actually movie': 921,
#  'movie left cutting room': 7246,
#  'left cutting room floor': 6322,
#  'james stewart margaret sullavan': 6011,
#  'supporting cast really make': 8982,
#  'br br don know': 1264,
#  'br br low budget': 2151,
#  'life br br film': 6373,
#  'spoiler coming br br': 8793,
#  'br br just want': 1980,
#  'tv series br br': 9340,
#  'br br movie original': 2333,
#  'br br rest cast': 2793,
#  'total recall starship troopers': 9256,
#  'film br br lead': 4985,
#  'br br lead character': 2031,
#  'best friend br br': 599,
#  'br br takes place': 3095,
#  'story br br just': 8895,
#  'br br good br': 1689,
#  'br good br br': 3494,
#  'movie ended br br': 7184,
#  'br br didn hurt': 1217,
#  'br didn hurt didn': 3425,
#  'didn hurt didn help': 4330,
#  'hurt didn help br': 5891,
#  'didn help br br': 4329,
#  'br br bad br': 978,
#  'br bad br br': 821,
#  'br br monster looks': 2237,
#  'character development br br': 3895,
#  'br br violence gore': 3266,
#  'br br ugly br': 3226,
#  'br ugly br br': 3705,
#  'br br memorable scene': 2209,
#  'br br acting 10': 862,
#  'br acting 10 story': 804,
#  'acting 10 story 10': 148,
#  'atmosphere 10 cinematography 10': 338,
#  '10 cinematography 10 character': 25,
#  'cinematography 10 character development': 3970,
#  '10 character development 10': 24,
#  'character development 10 special': 3894,
#  'development 10 special effects': 4266,
#  '10 special effects make': 36,
#  'special effects make 10': 8761,
#  'effects make 10 nudity': 4640,
#  'make 10 nudity sexuality': 6749,
#  '10 nudity sexuality 10': 34,
#  'music 10 direction 10': 7423,
#  '10 direction 10 br': 27,
#  'direction 10 br br': 4371,
#  '10 br br cheesiness': 6,
#  'br br cheesiness 10': 1123,
#  'br cheesiness 10 crappiness': 3413,
#  'cheesiness 10 crappiness 10': 3936,
#  '10 crappiness 10 br': 26,
#  'crappiness 10 br br': 4122,
#  '10 br br overall': 17,
#  'br br overall 10': 2479,
#  'br overall 10 br': 3579,
#  'overall 10 br br': 7607,
#  'br br recommend watch': 2758,
#  'die hard horror fans': 4343,
#  'br br www residenthazard': 3387,
#  'br www residenthazard com': 3734,
#  'film br br thought': 5026,
#  'br br william shatner': 3337,
#  'david letterman jay leno': 4183,
#  'john michael higgins daniel': 6058,
#  'michael higgins daniel roebuck': 6901,
#  'br br oh yes': 2452,
#  'br br basically plot': 1006,
#  'br br problem film': 2640,
#  'pun intended br br': 7940,
#  'film time br br': 5163,
#  'time br br thought': 9176,
#  'act way paper bag': 146,
#  'br br film offers': 1537,
#  'br br supporting cast': 3074,
#  'br br film features': 1496,
#  'br br saw original': 2856,
#  'make br br film': 6757,
#  'watch film br br': 9656,
#  'film br br movie': 4993,
#  'br br movie terrible': 2376,
#  'don ask br br': 4460,
#  'power br br did': 7874,
#  'br br did learn': 1208,
#  'br br things don': 3147,
#  'fell apart br br': 4900,
#  'br br end film': 1324,
#  'br br don watch': 1289,
#  'movie br br story': 7129,
#  'br br story young': 3061,
#  'camera work br br': 3800,
#  'summed follows br br': 8960,
#  'felt compelled comment film': 4905,
#  'comment film br br': 4049,
#  'long end br br': 6568,
#  'br br isn just': 1913,
#  'br br spoilers follow': 2987,
#  'br spoilers follow br': 3680,
#  'spoilers follow br br': 8809,
#  'bad guy br br': 474,
#  'entertaining movie br br': 4734,
#  'br br originally written': 2477,
#  'film didn br br': 5059,
#  'rest cast br br': 8184,
#  'br br film badly': 1449,
#  'br br gary taylor': 1654,
#  'br gary taylor aka': 3487,
#  'gary taylor aka gft': 5355,
#  'taylor aka gft amazon': 9024,
#  'aka gft amazon reviewer': 257,
#  'br br tom berenger': 3198,
#  'br br remember watching': 2789,
#  'film br br love': 4989,
#  'br br read reviews': 2688,
#  'second time br br': 8474,
#  'great movie br br': 5591,
#  'br br recommend movie': 2754,
#  'll like movie br': 6535,
#  'like movie br br': 6438,
#  'br br film simply': 1578,
#  'jokes just fall flat': 6065,
#  'br br thoroughly enjoyed': 3175,
#  'br br production values': 2647,
#  'tell story br br': 9036,
#  'alan rickman emma thompson': 262,
#  'acting camera work lighting': 164,
#  'br br good use': 1713,
#  'according dvd sleeve synopsis': 143,
#  'dvd sleeve synopsis br': 4601,
#  'sleeve synopsis br br': 8688,
#  'br br got movie': 1717,
#  've seen low budget': 9447,
#  'movie br br 10': 7028,
#  'br br 10 pretty': 843,
#  'happened past br br': 5657,
#  'funny movie br br': 5333,
#  'bad day black rock': 462,
#  'bad movies dangerous exotically': 508,
#  'br br movie utterly': 2384,
#  'painful watch bad movies': 7617,
#  'bad movies friends sit': 509,
#  'br br movie like': 2316,
#  'minds aspiring filmmakers thank': 6920,
#  'wile coyote road runner': 9761,
#  'disc looney tunes golden': 4399,
#  'looney tunes golden collection': 6614,
#  'tunes golden collection volume': 9324,
#  'br br story simple': 3051,
#  'don watch movie expecting': 4540,
#  'morgan freeman chris rock': 6992,
#  'br br soap opera': 2956,
#  'br br haven seen': 1827,
#  'br br spoilers ahead': 2982,
#  'spoilers ahead spoilers ahead': 8797,
#  'ahead spoilers ahead spoilers': 250,
#  'think really bad movie': 9110,
#  'fiancée karen selma blair': 4921,
#  'julia stiles selma blair': 6078,
#  'vote seven br br': 9531,
#  'seven br br title': 8582,
#  'br br title brazil': 3193,
#  'lone ranger clayton moore': 6559,
#  'bad acting bad special': 407,
#  'acting bad special effects': 155,
#  'goodnight mister tom absolutely': 5546,
#  'recently got chance watch': 8123,
#  'br br film good': 1509,
#  'goodnight mister tom extremely': 5549,
#  'dialogue rushed far fast': 4272,
#  'good way br br': 5545,
#  'br br movie really': 2348,
#  'br movie really bad': 3566,
#  'br br thing kept': 3121,
#  'better ways spend time': 666,
#  'bad acting really bad': 417,
#  'br br perfect example': 2545,
#  'make money br br': 6779,
#  'br br say good': 2869,
#  'joan crawford bette davis': 6040,
#  'watch br br 10': 9640,
#  'br br suffice say': 3070,
#  'br br poodle schnitz': 2611,
#  'br br movie bad': 2248,
#  'heart br br film': 5715,
#  'br br special mention': 2972,
#  'br br wrong br': 3382,
#  'br wrong br br': 3731,
#  'mild spoilers br br': 6906,
#  'br br haven read': 1826,
#  'fred astaire ginger rogers': 5292,
#  'let face music dance': 6349,
#  'hold special place heart': 5790,
#  'movie does great job': 7175,
#  'good job br br': 5502,
#  'job br br movie': 6051,
#  'br br movie gory': 2301,
#  'br br scene movie': 2898,
#  'br br hand story': 1809,
#  'possible spoilers br br': 7853,
#  'year old br br': 9964,
#  'film br br good': 4975,
#  'br br decide watch': 1181,
#  'film based true story': 4934,
#  'story goes br br': 8908,
#  'good intentions br br': 5501,
#  'br br definitely best': 1184,
#  'film goes br br': 5095,
#  'br br love film': 2135,
#  'cinema ultimate pervert art': 3966,
#  'br br orson welles': 2478,
#  'film br br ways': 5035,
#  'bad direction br br': 466,
#  'br br said film': 2839,
#  'long way br br': 6581,
#  'hits nail right head': 5787,
#  'went wrong br br': 9747,
#  'vice versa br br': 9502,
#  'br br 20 years': 852,
#  'movie best ve seen': 7026,
#  'best ve seen year': 633,
#  'way times br br': 9718,
#  'times br br plot': 9224,
#  'br br plot acting': 2565,
#  'good guy bad guy': 5493,
#  'br br does work': 1248,
#  'does work br br': 4433,
#  'rest film br br': 8187,
#  'br br kramer vs': 2019,
#  'br kramer vs kramer': 3525,
#  'today br br movie': 9236,
#  'br br story interesting': 3032,
#  'br br motion picture': 2242,
#  'time br br movie': 9164,
#  'br br movie things': 2377,
#  'br br overall movie': 2497,
#  'br br think films': 3162,
#  'br br way movie': 3329,
#  'video dvd br br': 9504,
#  'taking seriously br br': 9018,
#  'br br said just': 2840,
#  'br br tom wilkinson': 3200,
#  'uncle buck great outdoors': 9371,
#  'spoiler alert br br': 8789,
#  'br br favorite movie': 1422,
#  'br br robert mitchum': 2817,
#  'br br looked like': 2124,
#  'points 100 imdb 10': 7821,
#  'movie br br don': 7052,
#  'br br don let': 1265,
#  'robin hood men tights': 8237,
#  'way wet paper bag': 9720,
#  'br br film begins': 1454,
#  'van dien erika eleniak': 9397,
#  'dien erika eleniak coolio': 4345,
#  'br br isn plot': 1914,
#  'br br positive film': 2614,
#  'dvd vhs br br': 4604,
#  'limited screen time say': 6469,
#  'godzilla vs king ghidorah': 5416,
#  'did good job playing': 4309,
#  'good reason br br': 5522,
#  'taken seriously br br': 9010,
#  'br br tells story': 3104,
#  'doesn help br br': 4438,
#  'texas chain saw massacre': 9051,
#  'br br plot twists': 2602,
#  'br br horror fans': 1871,
#  'recommended br br 10': 8134,
#  'bad good just bad': 470,
#  'movie br br big': 7040,
#  'br br big disappointment': 1037,
#  'low budget horror flicks': 6696,
#  'mystery science theater 3000': 7442,
#  'science theater 3000 treatment': 8439,
#  'br br movie completely': 2266,
#  'death bed bed eats': 4205,
#  'br br huge fan': 1881,
#  'greatest movies ve seen': 5603,
#  'movies ve seen br': 7395,
#  've seen br br': 9427,
#  'enjoy movie br br': 4718,
#  'movie br br like': 7078,
#  'br br like said': 2069,
#  'funniest thing ve seen': 5314,
#  'movie kung fu movie': 7244,
#  'br br personally think': 2557,
#  'uncle br br course': 9370,
#  'rape scene br br': 7991,
#  'scene br br 10': 8399,
#  'minute film br br': 6931,
#  'film funny br br': 5091,
#  'br br br br': 1062,
#  'br br national velvet': 2423,
#  'credits br br movie': 4128,
#  'br br movie 10': 2243,
#  'really enjoy br br': 8073,
#  'trying create characters scrubs': 9319,
#  'trying create good writing': 9320,
#  'br br really don': 2705,
#  'black cat white cat': 715,
#  'br br produced directed': 2645,
#  'br br technical level': 3098,
#  'blair witch project 1999': 724,
#  'br br movie takes': 2373,
#  'worst films seen br': 9859,
#  'films seen br br': 5209,
#  'br br characters likable': 1114,
#  'br br film entertaining': 1488,
#  'takes cake br br': 9012,
#  'br br highly recommend': 1856,
#  'br highly recommend watch': 3511,
#  'bad guys br br': 476,
#  'just didn make sense': 6098,
#  'didn make sense br': 4335,
#  'make sense br br': 6787,
#  'bad movie br br': 490,
#  'bad bad bad acting': 430,
#  'waste time br br': 9591,
#  '12 year old boy': 53,
#  'worst thing ve seen': 9888,
#  'br br really didn': 2703,
#  'good night good luck': 5517,
#  'br br mary harron': 2193,
#  'br haven seen movie': 3504,
#  'movie worst movies seen': 7347,
#  'br br watched movie': 3321,
#  'br br main character': 2156,
#  'supporting cast pretty good': 8980,
#  'late night years ago': 6291,
#  'film low budget film': 5115,
#  'stick like sore thumb': 8860,
#  'br br early film': 1307,
#  'burt bacharach hal david': 3763,
#  'light hearted romantic comedy': 6387,
#  'br br walter matthau': 3280,
#  'things br br film': 9075,
#  'br br film stars': 1582,
#  'late eighties early nineties': 6289,
#  'br br acting bad': 868,
#  'rest movie br br': 8190,
#  'movie br br point': 7100,
#  'power rangers br br': 7875,
#  'great stuff br br': 5598,
#  'br br plot twist': 2601,
#  'mystery plot br br': 7441,
#  'plot br br bad': 7788,
#  'movie don waste time': 7179,
#  'br br plot simple': 2596,
#  'work br br movie': 9817,
#  'time better spent watching': 9144,
#  'beginning end br br': 564,
#  'br br really love': 2719,
#  'br br don speak': 1282,
#  'br br high points': 1850,
#  'good film br br': 5489,
#  'br br good movie': 1697,
#  'low budget br br': 6687,
#  'br br linnea quigley': 2086,
#  'br br reason watch': 2743,
#  'did really good job': 4320,
#  'br br really like': 2717,
#  'br br plot involves': 2581,
#  'film ends br br': 5080,
#  'br br yes know': 3397,
#  'does br br movie': 4407,
#  'br br isn bad': 1909,
#  'place br br say': 7753,
#  'br br say don': 2864,
#  'don make em like': 4485,
#  'make em like used': 6761,
#  'waste time money actors': 9596,
#  'movies seen br br': 7391,
#  'comedy br br 10': 4023,
#  'state art special effects': 8844,
#  'living movie year working': 6521,
#  'used try make sense': 9390,
#  'portray slavic woman half': 7840,
#  '14 year old son': 66,
#  'movie br br yes': 7154,
#  'br br yes acting': 3395,
#  'good laugh br br': 5505,
#  'reg reg reg reg': 8144,
#  'br br good old': 1699,
#  'away br br great': 373,
#  'going happen br br': 5427,
#  'br br mr mrs': 2405,
#  'br br final scene': 1622,
#  'movie br br pretty': 7102,
#  'story line br br': 8911,
#  'line br br movie': 6472,
#  'br br enjoy movie': 1340,
#  'bettie page br br': 668,
#  'yeah right br br': 9962,
#  'br br things considered': 3145,
#  'br br richard farnsworth': 2805,
#  'complete waste time money': 4061,
#  'br br movie opens': 2332,
#  '11 year old girl': 51,
#  'br br little girl': 2095,
#  'br br didn want': 1225,
#  'film set br br': 5143,
#  'contain spoilers br br': 4076,
#  'br br 10 br': 836,
#  'br 10 br br': 801,
#  'better job br br': 655,
#  'movies ve seen long': 7399,
#  've seen long time': 9441,
#  'worst films ve seen': 9860,
#  'stay away br br': 8847,
#  'br br fast moving': 1415,
#  'great film br br': 5581,
#  'james stewart doris day': 6010,
#  'steer clear br br': 8853,
#  'jack black kyle gass': 5992,
#  'original series br br': 7588,
#  'excellent movie br br': 4788,
#  'review br br stars': 8198,
#  'goes wrong br br': 5421,
#  'br br end movie': 1326,
#  'br br hard believe': 1814,
#  'human beings br br': 5875,
#  'evaluation looking absolute zero': 4768,
#  'ronin think gonna dislike': 8271,
#  'english br br story': 4710,
#  'late 60 early 70': 6283,
#  'big deal br br': 673,
#  'br br rated strong': 2673,
#  'make work br br': 6793,
#  'br br dialog good': 1199,
#  'year old high school': 9965,
#  'br br film 10': 1442,
#  'movie bad bad bad': 7018,
#  'bad bad bad good': 434,
#  'bad bad good way': 438,
#  'chore watch br br': 3951,
#  'quite possibly worst movie': 7968,
#  'acting worst ve seen': 182,
#  'br br favorite scene': 1424,
#  'br br story concerns': 3020,
#  'king kong wolf man': 6221,
#  'huge disappointment br br': 5869,
#  'funny fails br br': 5325,
#  'films collection br br': 5203,
#  'horror movies br br': 5836,
#  'don waste time br': 4531,
#  'time br br story': 9174,
#  'br br story similar': 3050,
#  'br br film fails': 1493,
#  'disappointed br br movie': 4393,
#  'br br end really': 1327,
#  'don expect blown away': 4472,
#  'loved ones br br': 6682,
#  'know low budget film': 6249,
#  'don let anybody tell': 4481,
#  'quality film br br': 7950,
#  'film br br waste': 5032,
#  'br br waste time': 3305,
#  'waste time ve seen': 9625,
#  'acting script camera work': 177,
#  'set design br br': 8581,
#  'film annoying br br': 4932,
#  'special effects br br': 8756,
#  'fairly explicit sex scene': 4833,
#  'br br opening scenes': 2471,
#  'true story christopher boyce': 9302,
#  'decades later br br': 4221,
#  'remote control fast forward': 8169,
#  'small town br br': 8693,
#  'movie 90 minutes long': 7011,
#  'br br conclusion don': 1144,
#  'help film br br': 5736,
#  'film br br film': 4972,
#  'video camera br br': 9503,
#  'br br maybe just': 2197,
#  'robert stack dorothy malone': 8234,
#  'level br br great': 6365,
#  'film suppose good idea': 5156,
#  'wasn case watching dodgy': 9571,
#  'film shot darkly impossible': 5148,
#  'dialogue maybe bad thing': 4270,
#  'just saw movie tv': 6159,
#  'film history br br': 5098,
#  'saps sea br br': 8324,
#  'br br story like': 3036,
#  'sidney bruhl michael caine': 8658,
#  'clifford anderson christopher reeve': 3989,
#  'br br good thriller': 1712,
#  'going crap br br': 5425,
#  'doubt best ghost stories': 4546,
#  'best ghost stories film': 600,
#  'directed siu tung ching': 4359,
#  'ling choi sin played': 6486,
#  'trek perilous wolves crazy': 9287,
#  'br br ling choi': 2085,
#  'br ling choi sin': 3536,
#  'ling choi sin meets': 6485,
#  'mysterious young girl lives': 7436,
#  'innocent ling choi sin': 5939,
#  'ling choi sin fall': 6484,
#  'fall love br br': 4839,
#  'love br br ling': 6655,
#  'ling choi sin sort': 6488,
#  'woods tries protect monk': 9803,
#  'monk trying kill spirits': 6974,
#  'scarves movie genuinely flows': 8392,
#  'nice br br end': 7479,
#  'ling ashes home proper': 6483,
#  'br br beautiful story': 1013,
#  'end yin ling choi': 4686,
#  'ling choi sin ride': 6487,
#  'sun enchanting rainbow know': 8965,
#  'br br really good': 2711,
#  'movie br br director': 7050,
#  'br br just watch': 1982,
#  'henry portrait serial killer': 5738,
#  'hong kong br br': 5810,
#  'nominated best song lost': 7494,
#  'br br thing like': 3122,
#  'br br available dvd': 963,
#  'br br nicholas cage': 2432,
#  'robert duvall james earl': 8231,
#  'duvall james earl jones': 4592,
#  'just wasted hours life': 6172,
#  'wasted hours life watching': 9633,
#  'hours life watching movie': 5853,
#  'fell asleep br br': 4902,
#  'really good br br': 8080,
#  'classic br br young': 3979,
#  'br br story good': 3029,
#  'good true br br': 5543,
#  'view film br br': 9509,
#  'film br br thing': 5024,
#  'film br br does': 4964,
#  'plot movie pretty simple': 7807,
#  'goes downhill br br': 5418,
#  'br br plot predictable': 2590,
#  'br br want good': 3286,
#  'action scenes br br': 192,
#  'movie br br honestly': 7071,
#  'br br maybe ll': 2198,
#  'pay attention br br': 7653,
#  'perry smith dick hickock': 7714,
#  'br br great fun': 1743,
#  'br br avoid unless': 969,
#  'br br story new': 3042,
#  'fun watch br br': 5311,
#  'films time br br': 5212,
#  'br br watched film': 3319,
#  'br br don think': 1285,
#  'br br avoid like': 967,
#  'jean claude van damme': 6018,
#  'br br van damme': 3243,
#  'br br 20 minutes': 851,
#  'film br br story': 5021,
#  'br br ll movie': 2106,
#  'time br br watch': 9179,
#  'br br film needs': 1534,
#  'br br final minutes': 1619,
#  'awful movie br br': 389,
#  'looking forward seeing movie': 6601,
#  'poorly written poorly directed': 7835,
#  'written poorly directed poorly': 9941,
#  've seen movie times': 9451,
#  'seen movie times time': 8521,
#  'like watching train wreck': 6463,
#  'br br movie contains': 2267,
#  'don know br br': 4477,
#  'movie deserves higher rating': 7167,
#  'movie probably worst movie': 7272,
#  'probably worst movie seen': 7913,
#  'better movie br br': 658,
#  'movie br br waste': 7145,
#  'end movie br br': 4673,
#  'does really good job': 4430,
#  've seen better acting': 9424,
#  'claude van damme br': 3980,
#  'van damme br br': 9396,
#  'br br special effects': 2971,
#  'special effects really good': 8764,
#  'br br long time': 2119,
#  'fans br br 10': 4860,
#  'time ve seen movie': 9217,
#  'br br film quite': 1556,
#  'violence gore br br': 9515,
#  'role lucille ball rachel': 8247,
#  'lucille ball rachel york': 6730,
#  'portrayal lucy absolutely awful': 7843,
#  'role lucille ball tough': 8248,
#  'portrayal lucy episodes love': 7844,
#  'year old video camera': 9966,
#  'direction br br bad': 4373,
#  'br br bad film': 981,
#  'doing br br film': 4455,
#  'film classic br br': 5043,
#  'br br best thing': 1032,
#  'br best thing movie': 828,
#  'movie total waste time': 7316,
#  'br br story moves': 3040,
#  'shakti kapoor crime master': 8606,
#  'kapoor crime master gogo': 6189,
#  'comedy br br movie': 4025,
#  'br br avoid costs': 965,
#  'br br christopher walken': 1128,
#  'br br laugh loud': 2026,
#  'pleasure watch br br': 7784,
#  'br br 10 stars': 846,
#  'mitchell spins grave time': 6955,
#  'joanne whalley title character': 6049,
#  'hellishly bad script score': 5728,
#  'scarlett just amazingly lousy': 8381,
#  'br br joe amato': 1939,
#  'sex scenes br br': 8591,
#  'br br movie presents': 2342,
#  'bad movies takes cake': 510,
#  'good cop bad cop': 5484,
#  'avoid costs br br': 363,
#  'br br years ago': 3392,
#  'prime minister br br': 7902,
#  'br br film br': 1461,
#  'br film br br': 3477,
#  'br br redeeming feature': 2771,
#  'br br basic premise': 1001,
#  'br br acting wasn': 903,
#  'spoilers end br br': 8808,
#  'end br br overall': 4665,
#  'making movie br br': 6811,
#  'film br br don': 4965,
#  'br br say film': 2868,
#  'twist ending br br': 9347,
#  'br br bright spot': 1070,
#  'br bright spot film': 3409,
#  'low budget plot line': 6708,
#  'br br grade br': 1719,
#  'br grade br br': 3500,
#  'grade br br dvd': 5563,
#  'br br dvd extras': 1304,
#  'movie br br imagine': 7073,
#  'br br half hour': 1801,
#  'br br beautifully shot': 1015,
#  'br br stars film': 2996,
#  'br br john hurt': 1944,
#  'read book br br': 8022,
#  'br br story really': 3047,
#  'good script br br': 5524,
#  'br br excellent acting': 1361,
#  'br br movie worth': 2394,
#  'vote br br title': 9530,
#  'br br story involves': 3033,
#  'br br highly recommended': 1857,
#  'br br performances good': 2547,
#  'film br br ending': 4968,
#  'br br thought provoking': 3182,
#  'remade dr doolittle nutty': 8158,
#  'dr doolittle nutty professor': 4555,
#  'vehicles just tepid remakes': 9496,
#  'come doing standup routine': 4013,
#  'man body inhabits truck': 6820,
#  'like chris rock chris': 6413,
#  'movie worst ve seen': 7348,
#  'movie real br br': 7280,
#  'love br br just': 6653,
#  'br br just love': 1965,
#  'plot br br don': 7789,
#  'br br don waste': 1288,
#  'br don waste time': 3452,
#  'peter cushing christopher lee': 7721,
#  'cushing christopher lee ingrid': 4155,
#  'christopher lee ingrid pitt': 3955,
#  'role br br story': 8244,
#  'films ve seen br': 5215,
#  'br br memorable film': 2207,
#  'br br film went': 1607,
#  'love low budget horror': 6672,
#  'low budget horror movies': 6699,
#  'br br yes movie': 3398,
#  'br br premise interesting': 2627,
#  'br br really makes': 2721,
#  'epic movie date movie': 4745,
#  'br br randolph scott': 2664,
#  'flashback scenes br br': 5244,
#  'scenes br br movie': 8408,
#  'br br movie light': 2315,
#  'mother sandy sigourney weaver': 7001,
#  'br br spoiler alert': 2977,
#  'family br br film': 4848,
#  'written directed dan harris': 9940,
#  'self conscious br br': 8539,
#  'mama rose television version': 6813,
#  'vegas live concert special': 9491,
#  'vegas midler performing live': 9492,
#  'called look good proves': 3783,
#  'segues way variety musical': 8538,
#  'hysterical bette treats rose': 5895,
#  'wind beneath wings beaches': 9765,
#  'beneath wings beaches dazzling': 578,
#  'comedy entertainment midler fans': 4028,
#  'liked movie br br': 6467,
#  'movie br br problem': 7104,
#  'kid movie br br': 6204,
#  'movie br br overall': 7096,
#  'br br want watch': 3293,
#  'br br film isn': 1518,
#  'br br george scott': 1664,
#  'spend time br br': 8776,
#  'br br having said': 1832,
#  'completely ridiculous br br': 4065,
#  'fi channel br br': 4916,
#  'movies ve seen just': 7397,
#  'robert duvall tommy lee': 8232,
#  'duvall tommy lee jones': 4593,
#  'want br br interesting': 9540,
#  'actors did fine job': 207,
#  'br br thing film': 3116,
#  'story film br br': 8906,
#  'situation br br film': 8678,
#  'kiss kiss bang bang': 6226,
#  'spoiler warning br br': 8795,
#  'br br today standards': 3197,
#  'good br br nice': 5473,
#  'die hard lethal weapon': 4344,
#  'br br final analysis': 1615,
#  'motion picture br br': 7003,
#  'br br sets costumes': 2933,
#  'book story br br': 769,
#  'based novel jonathan safran': 544,
#  'novel jonathan safran foer': 7504,
#  'woman saved grandfather nazis': 9785,
#  'love cheesy horror movies': 6668,
#  'horror movies ve seen': 5839,
#  '10 minutes br br': 32,
#  'worst movie ve seen': 9876,
#  'movie ve seen entire': 7322,
#  've seen entire life': 9430,
#  'seen pretty bad movies': 8526,
#  've seen worse movie': 9467,
#  'film br br storyline': 5022,
#  'br br 10 come': 837,
#  'original movie br br': 7584,
#  'br br actors playing': 916,
#  'shown film br br': 8652,
#  'look like citizen kane': 6592,
#  'like citizen kane br': 6414,
#  'citizen kane br br': 3972,
#  '10 br br kind': 12,
#  'movie dull dull dull': 7181,
#  'rest case br br': 8182,
#  'case br br movie': 3842,
#  'thirty years ago br': 9116,
#  'years ago br br': 9971,
#  'br br movie gets': 2298,
#  'br br giving away': 1672,
#  'laugh hard br br': 6301,
#  'br br love movie': 2141,
#  'pulp fiction br br': 7939,
#  'br br like watching': 2074,
#  'end film br br': 4672,
#  'quality movie br br': 7952,
#  'movie br br lot': 7083,
#  'br br death bed': 1179,
#  'br br conclusion movie': 1148,
#  'br br movie clearly': 2264,
#  'br br adam west': 923,
#  'adam west burt ward': 234,
#  'sound effects br br': 8745,
#  'br br richard gere': 2806,
#  'br br movie isn': 2310,
#  'big score br br': 686,
#  'br br steven seagal': 3008,
#  'movie enjoyable br br': 7187,
#  'br br william macy': 3336,
#  'know going br br': 6246,
#  'going br br film': 5422,
#  'br br film watch': 1606,
#  'line delivery br br': 6473,
#  'br br nicolas cage': 2433,
#  'minutes br br want': 6939,
#  'br br want movie': 3289,
#  'look like high school': 6593,
#  'does pretty good job': 4428,
#  'br br kept waiting': 1994,
#  '20 minutes br br': 78,
#  'target audience br br': 9021,
#  'better br br grade': 644,
#  '40 year old virgin': 87,
#  'know better br br': 6230,
#  'br br worth catching': 3364,
#  'best movie ve seen': 618,
#  'movie ve seen certainly': 7321,
#  'movies days br br': 7378,
#  'br br ll end': 2102,
#  'james cain novel postman': 6005,
#  'cain novel postman rings': 3779,
#  'novel postman rings twice': 7505,
#  'film br br years': 5038,
#  'story br br 10': 8892,
#  'br br celluloid rehab': 1101,
#  'br br does make': 1246,
#  'br br stay away': 3004,
#  'br br movie perfect': 2336,
#  'br br course movie': 1159,
#  'br br example movie': 1358,
#  'br br time goes': 3186,
#  'better br br just': 645,
#  'br br just remember': 1971,
#  'freddy dead final nightmare': 5293,
#  'br br freddy dead': 1640,
#  'br freddy dead final': 3486,
#  'br br english version': 1337,
#  'br br people say': 2541,
#  'lost count number times': 6618,
#  'bad movie really really': 503,
#  'story br br film': 8894,
#  'br br film gets': 1505,
#  'film gets high marks': 5093,
#  'quite enjoyable br br': 7962,
#  'films br br film': 5193,
#  'br br kurt russell': 2022,
#  'guilty pleasure br br': 5623,
#  'br br eye candy': 1370,
#  'br br movie great': 2303,
#  'know talking br br': 6251,
#  'br br original series': 2476,
#  'lot better br br': 6621,
#  'cult classic br br': 4143,
#  'br br like films': 2059,
#  'br br cast good': 1089,
#  'film know br br': 5107,
#  'like did br br': 6416,
#  'did br br ratings': 4292,
#  'story br br unlike': 8901,
#  'br br look movie': 2123,
#  'horror film br br': 5826,
#  'bad acting low budget': 414,
#  'br br fact film': 1373,
#  'doesn make sense movie': 4447,
#  'good actor br br': 5457,
#  'br br seriously movie': 2932,
#  'movie ve seen long': 7328,
#  'seen long time ve': 8514,
#  'long time ve seen': 6580,
#  've seen quite movies': 9457,
#  'time br br reason': 9171,
#  'br br reason gave': 2739,
#  'reason gave movie instead': 8111,
#  'disappointing movie br br': 4395,
#  'br br suspension disbelief': 3093,
#  'acting use term loosely': 181,
#  'br br rented movie': 2792,
#  'movie br br problems': 7105,
#  'aspect film br br': 335,
#  'film br br just': 4982,
#  'br br best scenes': 1031,
#  'br best scenes movie': 826,
#  'br br main problem': 2161,
#  'br main problem movie': 3548,
#  'action movies br br': 190,
#  'movies br br movie': 7367,
#  'br br movie extremely': 2283,
#  'seen believed br br': 8490,
#  'br br highlights include': 1855,
#  'burned burned burned burned': 3762,
#  'br br needless say': 2426,
#  'br br far good': 1409,
#  'group high school students': 5608,
#  'br br did watch': 1214,
#  'br br great actors': 1727,
#  'awful awful awful br': 383,
#  'awful awful br br': 384,
#  'kind movie br br': 6213,
#  'movie br br film': 7059,
#  'br br film unfortunately': 1599,
#  'br br reading probably': 2690,
#  'know mean br br': 6250,
#  'br br say ve': 2886,
#  'br br just say': 1973,
#  'twilight zone br br': 9343,
#  'br br esther rolle': 1354,
#  'br br best performance': 1029,
#  'watch br br music': 9647,
#  'br br music film': 2411,
#  'br br overall watch': 2514,
#  'mind br br film': 6912,
#  'br br background music': 975,
#  'br br camera work': 1078,
#  'br br people said': 2540,
#  'movie did good job': 7169,
#  'br br finally movie': 1632,
#  'don make like anymore': 4488,
#  'br br great story': 1761,
#  'br br story starts': 3052,
#  'br br characters movie': 1115,
#  'watching br br ve': 9680,
#  'model turned bounty hunter': 6967,
#  'wider audience br br': 9757,
#  'come rescue br br': 4019,
#  'br br technically movie': 3100,
#  'br br parts movie': 2528,
#  'br br know child': 2007,
#  'br br robin williams': 2820,
#  'br br tim robbins': 3184,
#  'br br gung ho': 1791,
#  '21st century br br': 85,
#  '30 minutes br br': 86,
#  'trust br br 10': 9309,
#  ...}

# %%
cv.vocabulary_.items()
# Out:
# dict_items([('important story br br', 5923), ('happy ending br br', 5663), ('ve seen ve seen', 9464), ('br br far know', 1411), ('br br actors great', 912), ('entire movie br br', 4741), ('br br given film', 1669), ('br br downside movie', 1294), ('br br opening scene', 2470), ('different br br movie', 4346), ('br br movie does', 2277), ('just don make movies', 6108), ('don make movies like', 4490), ('make movies like anymore', 6784), ('br br fact actually', 1371), ('love smell napalm morning', 6675), ('br br lot people', 2133), ('br br movie based', 2249), ('possible way br br', 7854), ('br br true classic', 3211), ('br br rating 10', 2676), ('br br ll rooting', 2108), ('br br great film', 1741), ('br br film funny', 1503), ('watching old black white', 9690), ('br br bad things', 992), ('br br ve seen', 3255), ('ve seen half dozen', 9435), ('seen half dozen times', 8507), ('half dozen times time', 5640), ('br br does film', 1244), ('br br movie funny', 2297), ('film extremely low budget', 5085), ('br br probably best', 2634), ('nightmare elm street series', 7491), ('br br performances really', 2550), ('br br don fooled', 1261), ('br br recommended fans', 2762), ('fast times ridgemont high', 4880), ('really bad movie just', 8062), ('br br slow paced', 2952), ('don think ve seen', 4513), ('think ve seen episode', 9111), ('episode wrap like say', 4751), ('wrap like say ll', 9907), ('like say ll remember', 6454), ('say ll remember memory', 8363), ('ll remember memory forever', 6542), ('ve seen episode conclusion', 9431), ('hope catch day goes', 5814), ('catch day goes air', 3861), ('day goes air good', 4192), ('big time br br', 689), ('human br br movie', 5876), ('john turturro tim blake', 6060), ('turturro tim blake nelson', 9333), ('ve seen lot worse', 9446), ('johnny cammareri danny aiello', 6062), ('wanted like really did', 9557), ('love film br br', 6669), ('br br going try', 1682), ('br br favor don', 1418), ('worst movies ve seen', 9882), ('horror movie br br', 5834), ('br br rate 10', 2667), ('br br wonderful film', 3352), ('won academy award best', 9787), ('academy award best picture', 136), ('tourist trap genuinely spooky', 9261), ('low budget horror film', 6693), ('contains extremely strange atmosphere', 4079), ('schmoeller returned make genre', 8418), ('tourist trap definitely best', 9260), ('best horror film want', 601), ('br br rated pg', 2672), ('br br eric stoltz', 1351), ('life br br really', 6378), ('br br really film', 2709), ('bette davis joan crawford', 636), ('movie seen entire life', 7298), ('bar br br movie', 540), ('br br movie complete', 2265), ('br br like movies', 2066), ('movies like bad movies', 7386), ('br br great movie', 1751), ('br br makes film', 2182), ('br br worth watching', 3374), ('film br br dialogue', 4959), ('credits roll br br', 4131), ('br br didn like', 1219), ('lock stock smoking barrels', 6558), ('br br actually movie', 921), ('movie left cutting room', 7246), ('left cutting room floor', 6322), ('james stewart margaret sullavan', 6011), ('supporting cast really make', 8982), ('br br don know', 1264), ('br br low budget', 2151), ('life br br film', 6373), ('spoiler coming br br', 8793), ('br br just want', 1980), ('tv series br br', 9340), ('br br movie original', 2333), ('br br rest cast', 2793), ('total recall starship troopers', 9256), ('film br br lead', 4985), ('br br lead character', 2031), ('best friend br br', 599), ('br br takes place', 3095), ('story br br just', 8895), ('br br good br', 1689), ('br good br br', 3494), ('movie ended br br', 7184), ('br br didn hurt', 1217), ('br didn hurt didn', 3425), ('didn hurt didn help', 4330), ('hurt didn help br', 5891), ('didn help br br', 4329), ('br br bad br', 978), ('br bad br br', 821), ('br br monster looks', 2237), ('character development br br', 3895), ('br br violence gore', 3266), ('br br ugly br', 3226), ('br ugly br br', 3705), ('br br memorable scene', 2209), ('br br acting 10', 862), ('br acting 10 story', 804), ('acti ...

# %%
sorted(cv.vocabulary_.items(), key=lambda x: x[1], reverse=True)
# Out:
# [('zu warriors magic mountain', 9999),
#  ('zombie movie br br', 9998),
#  ('zero day br br', 9997),
#  ('zero 10 br br', 9996),
#  ('young woman just met', 9995),
#  ('young woman br br', 9994),
#  ('young randolph scott dean', 9993),
#  ('young man br br', 9992),
#  ('young adults br br', 9991),
#  ('young actor br br', 9990),
#  ('yes br br movie', 9989),
#  ('yeh dil na hota', 9988),
#  ('years right understand initial', 9987),
#  ('years passed br br', 9986),
#  ('years old time saw', 9985),
#  ('years old br br', 9984),
#  ('years later saw movie', 9983),
#  ('years later br br', 9982),
#  ('years earlier br br', 9981),
#  ('years come br br', 9980),
#  ('years br br seen', 9979),
#  ('years br br real', 9978),
#  ('years br br movie', 9977),
#  ('years br br film', 9976),
#  ('years ago ve watched', 9975),
#  ('years ago saw movie', 9974),
#  ('years ago saw film', 9973),
#  ('years ago haven seen', 9972),
#  ('years ago br br', 9971),
#  ('years 100 stars men', 9970),
#  ('years 100 laughs good', 9969),
#  ('year olds br br', 9968),
#  ('year old virgin little', 9967),
#  ('year old video camera', 9966),
#  ('year old high school', 9965),
#  ('year old br br', 9964),
#  ('year high school reunion', 9963),
#  ('yeah right br br', 9962),
#  ('yankee doodle dandy lady', 9961),
#  ('yadda yadda br br', 9960),
#  ('wyatt earp bat masterson', 9959),
#  ('www youtube com watch', 9958),
#  ('www nixflix com detailed', 9957),
#  ('www imdb com title', 9956),
#  ('wwe tag team championship', 9955),
#  ('wrong wrong br br', 9954),
#  ('wrong utter pretentious nonsense', 9953),
#  ('wrong reasons br br', 9952),
#  ('wrong place wrong time', 9951),
#  ('wrong movie br br', 9950),
#  ('wrong mike myers example', 9949),
#  ('wrong life god comes', 9948),
#  ('wrong just treasure takes', 9947),
#  ('wrong idea br br', 9946),
#  ('wrong film br br', 9945),
#  ('wrong elton harriet fallen', 9944),
#  ('wrong br br movie', 9943),
#  ('wrong br br ll', 9942),
#  ('written poorly directed poorly', 9941),
#  ('written directed dan harris', 9940),
#  ('written acted br br', 9939),
#  ('written 12 year old', 9938),
#  ('written 10 year old', 9937),
#  ('writing topnotch short story', 9936),
#  ('writing strong performances grade', 9935),
#  ('writing screenplay written directly', 9934),
#  ('writing review br br', 9933),
#  ('writing recipes saving time', 9932),
#  ('writing directing br br', 9931),
#  ('writing bad acting bad', 9930),
#  ('writing acting br br', 9929),
#  ('writer director paul thomas', 9928),
#  ('writer director mike binder', 9927),
#  ('writer director br br', 9926),
#  ('write review warn people', 9925),
#  ('write review br br', 9924),
#  ('write produce direct reason', 9923),
#  ('write piece junk book', 9922),
#  ('write panning review goes', 9921),
#  ('write novels combination atlantian', 9920),
#  ('write movie forced hundreds', 9919),
#  ('write minimum 10 lines', 9918),
#  ('write list factual errors', 9917),
#  ('write like kind music', 9916),
#  ('write home br br', 9915),
#  ('write comment br br', 9914),
#  ('write atlantian got sort', 9913),
#  ('write 10 lines text', 9912),
#  ('wretched material entertaining christopher', 9911),
#  ('wrenching story seriously figured', 9910),
#  ('wrenching experience visited time', 9909),
#  ('wrap movie br br', 9908),
#  ('wrap like say ll', 9907),
#  ('worthy academy award nomination', 9906),
#  ('worthwhile jesus christ people', 9905),
#  ('worthwhile film br br', 9904),
#  ('worthless island changed worthwhile', 9903),
#  ('worth watching rating 10', 9902),
#  ('worth watching br br', 9901),
#  ('worth watch br br', 9900),
#  ('worth wait br br', 9899),
#  ('worth time br br', 9898),
#  ('worth seeing br br', 9897),
#  ('worth renting br br', 9896),
#  ('worth rental br br', 9895),
#  ('worth price admission br', 9894),
#  ('worth look br br', 9893),
#  ('worth effort br br', 9892),
#  ('worth checking br br', 9891),
#  ('worst ve seen ve', 9890),
#  ('worst ve seen br', 9889),
#  ('worst thing ve seen', 9888),
#  ('worst thing carlos mencia', 9887),
#  ('worst spent hours life', 9886),
#  ('worst seen br br', 9885),
#  ('worst piece crap ve', 9884),
#  ('worst performance ve seen', 9883),
#  ('worst movies ve seen', 9882),
#  ('worst movies time list', 9881),
#  ('worst movies seen plot', 9880),
#  ('worst movies seen life', 9879),
#  ('worst movies seen br', 9878),
#  ('worst movie ve watched', 9877),
#  ('worst movie ve seen', 9876),
#  ('worst movie time probably', 9875),
#  ('worst movie seen years', 9874),
#  ('worst movie seen ve', 9873),
#  ('worst movie seen thought', 9872),
#  ('worst movie seen seen', 9871),
#  ('worst movie seen movie', 9870),
#  ('worst movie seen life', 9869),
#  ('worst movie seen entire', 9868),
#  ('worst movie seen br', 9867),
#  ('worst movie seen bad', 9866),
#  ('worst movie br br', 9865),
#  ('worst horror movies seen', 9864),
#  ('worst horror movie ve', 9863),
#  ('worst horror movie seen', 9862),
#  ('worst horror film seen', 9861),
#  ('worst films ve seen', 9860),
#  ('worst films seen br', 9859),
#  ('worst films br br', 9858),
#  ('worst film ve seen', 9857),
#  ('worst film seen years', 9856),
#  ('worst film seen year', 9855),
#  ('worst film seen say', 9854),
#  ('worst film seen long', 9853),
#  ('worst film seen life', 9852),
#  ('worst film saw year', 9851),
#  ('worst film br br', 9850),
#  ('worst actors ve seen', 9849),
#  ('worst acting ve seen', 9848),
#  ('worse worse br br', 9847),
#  ('worse movies ve seen', 9846),
#  ('worse imagined br br', 9845),
#  ('worse br br movie', 9844),
#  ('worse br br just', 9843),
#  ('worse br br film', 9842),
#  ('world war ii soon', 9841),
#  ('world war ii film', 9840),
#  ('world war ii era', 9839),
#  ('world war ii br', 9838),
#  ('world war br br', 9837),
#  ('world greatest technology scientists', 9836),
#  ('world english landowners instantly', 9835),
#  ('world cinema br br', 9834),
#  ('world br br unfortunately', 9833),
#  ('world br br movie', 9832),
#  ('world br br like', 9831),
#  ('world br br hope', 9830),
#  ('world br br great', 9829),
#  ('world br br film', 9828),
#  ('works quite br br', 9827),
#  ('works levels br br', 9826),
#  ('works just misses mark', 9825),
#  ('works br br film', 9824),
#  ('work case br br', 9823),
#  ('work br br think', 9822),
#  ('work br br story', 9821),
#  ('work br br saw', 9820),
#  ('work br br really', 9819),
#  ('work br br problem', 9818),
#  ('work br br movie', 9817),
#  ('work br br just', 9816),
#  ('work br br good', 9815),
#  ('work br br film', 9814),
#  ('work br br basically', 9813),
#  ('work attracts attention apart', 9812),
#  ('work art br br', 9811),
#  ('work 10 year hiatus', 9810),
#  ('words words theirs haunted', 9809),
#  ('words don waste time', 9808),
#  ('words big disappointment low', 9807),
#  ('woody allen wanted know', 9806),
#  ('woody allen mel brooks', 9805),
#  ('woody allen br br', 9804),
#  ('woods tries protect monk', 9803),
#  ('wonderful piece book scarlett', 9802),
#  ('wonderful film br br', 9801),
#  ('wonder british film industry', 9800),
#  ('won spoil br br', 9799),
#  ('won regret br br', 9798),
#  ('won oscar best supporting', 9797),
#  ('won oscar best picture', 9796),
#  ('won golden globe best', 9795),
#  ('won disappointed br br', 9794),
#  ('won care br br', 9793),
#  ('won best supporting actress', 9792),
#  ('won best supporting actor', 9791),
#  ('won best picture oscar', 9790),
#  ('won best actor oscar', 9789),
#  ('won academy award performance', 9788),
#  ('won academy award best', 9787),
#  ('women avocado jungle death', 9786),
#  ('woman saved grandfather nazis', 9785),
#  ('woman loves br br', 9784),
#  ('woman chatting asian guy', 9783),
#  ('woman br br film', 9782),
#  ('wolf man frankenstein monster', 9781),
#  ('witnesses film br br', 9780),
#  ('witch project br br', 9779),
#  ('wishful thinking br br', 9778),
#  ('wish heart makes love', 9777),
#  ('wins end br br', 9776),
#  ('winning movies worth seeing', 9775),
#  ('winning golden globe nominated', 9774),
#  ('winning brit sex comedy', 9773),
#  ('wind isn read novel', 9772),
#  ('wind howling cracks br', 9771),
#  ('wind fan disappointed watch', 9770),
#  ('wind fan book movie', 9769),
#  ('wind children make difference', 9768),
#  ('wind blown continental winter', 9767),
#  ('wind beneath wings best', 9766),
#  ('wind beneath wings beaches', 9765),
#  ('win war br br', 9764),
#  ('william powell philo vance', 9763),
#  ('william powell myrna loy', 9762),
#  ('wile coyote road runner', 9761),
#  ('wife morgan gene tierney', 9760),
#  ('wife jada pinkett smith', 9759),
#  ('wife daughter br br', 9758),
#  ('wider audience br br', 9757),
#  ('wide range material short', 9756),
#  ('wide open br br', 9755),
#  ('wicked little things zombies', 9754),
#  ('white horse type rescue', 9753),
#  ('whilst walking desert travels', 9752),
#  ('whatsoever br br story', 9751),
#  ('wet hot american summer', 9750),
#  ('west point military academy', 9749),
#  ('west point civil war', 9748),
#  ('went wrong br br', 9747),
#  ('went movie really expecting', 9746),
#  ('went movie low expectations', 9745),
#  ('went movie expecting movie', 9744),
#  ('went making br br', 9743),
#  ('went list makes engaging', 9742),
#  ('went kill sam film', 9741),
#  ('went horribly wrong br', 9740),
#  ('went high school late', 9739),
#  ('went gave proved super', 9738),
#  ('went flower stores demolitions', 9737),
#  ('went far kept arms', 9736),
#  ('went crazy murdered family', 9735),
#  ('went cinema felt like', 9734),
#  ('went br br watched', 9733),
#  ('went br br like', 9732),
#  ('went br br dumped', 9731),
#  ('went bought case cognac', 9730),
#  ('week member tribe leaves', 9729),
#  ('wedding attempts lay low', 9728),
#  ('website bad cheesy movies', 9727),
#  ('web site chuck norris', 9726),
#  ('weaving character superfluous appears', 9725),
#  ('weak script br br', 9724),
#  ('weak movie honestly just', 9723),
#  ('ways br br ll', 9722),
#  ('ways br br film', 9721),
#  ('way wet paper bag', 9720),
#  ('way way br br', 9719),
#  ('way times br br', 9718),
#  ('way spend hour half', 9717),
#  ('way spend couple hours', 9716),
#  ('way possible br br', 9715),
#  ('way movie br br', 9714),
#  ('way mark br br', 9713),
#  ('way long br br', 9712),
#  ('way home br br', 9711),
#  ('way film br br', 9710),
#  ('way end br br', 9709),
#  ('way did br br', 9708),
#  ('way br br think', 9707),
#  ('way br br story', 9706),
#  ('way br br people', 9705),
#  ('way br br overall', 9704),
#  ('way br br movie', 9703),
#  ('way br br main', 9702),
#  ('way br br lot', 9701),
#  ('way br br film', 9700),
#  ('way br br don', 9699),
#  ('way br br bad', 9698),
#  ('way br br 10', 9697),
#  ('watching unkempt stink ladened', 9696),
#  ('watching time br br', 9695),
#  ('watching scarlett miniseries worst', 9694),
#  ('watching piece crap br', 9693),
#  ('watching paint dry grass', 9692),
#  ('watching paint dry br', 9691),
#  ('watching old black white', 9690),
#  ('watching movie felt like', 9689),
#  ('watching movie br br', 9688),
#  ('watching happens invested time', 9687),
#  ('watching film like watching', 9686),
#  ('watching film late night', 9685),
#  ('watching film felt like', 9684),
#  ('watching film br br', 9683),
#  ('watching exact years right', 9682),
#  ('watching end br br', 9681),
#  ('watching br br ve', 9680),
#  ('watching br br movie', 9679),
#  ('watching br br film', 9678),
#  ('watching br br best', 9677),
#  ('watching br br 10', 9676),
#  ('watched movie years ago', 9675),
#  ('watched movie times time', 9674),
#  ('watched movie second time', 9673),
#  ('watched film years ago', 9672),
#  ('watched film br br', 9671),
#  ('watched 2003 10 dir', 9670),
#  ('watch ve seen times', 9669),
#  ('watch times br br', 9668),
#  ('watch stupid movie parents', 9667),
#  ('watch second half movie', 9666),
#  ('watch punishment don watch', 9665),
#  ('watch original movie left', 9664),
#  ('watch movies br br', 9663),
#  ('watch movie ve seen', 9662),
#  ('watch movie second time', 9661),
#  ('watch movie read book', 9660),
#  ('watch movie like watching', 9659),
#  ('watch movie br br', 9658),
#  ('watch let start saying', 9657),
#  ('watch film br br', 9656),
#  ('watch feel like watching', 9655),
#  ('watch enjoy br br', 9654),
#  ('watch end br br', 9653),
#  ('watch don waste time', 9652),
#  ('watch br br watch', 9651),
#  ('watch br br story', 9650),
#  ('watch br br really', 9649),
#  ('watch br br overall', 9648),
#  ('watch br br music', 9647),
#  ('watch br br movie', 9646),
#  ('watch br br like', 9645),
#  ('watch br br just', 9644),
#  ('watch br br good', 9643),
#  ('watch br br film', 9642),
#  ('watch br br clichés', 9641),
#  ('watch br br 10', 9640),
#  ('wasting time br br', 9639),
#  ('wasting 90 minutes life', 9638),
#  ('wasted time watching movie', 9637),
#  ('wasted time br br', 9636),
#  ('wasted roles stereotypical frightened', 9635),
#  ('wasted money br br', 9634),
#  ('wasted hours life watching', 9633),
#  ('wasted hour half life', 9632),
#  ('wasted 90 minutes life', 9631),
#  ('waste time watching unless', 9630),
#  ('waste time watching movie', 9629),
#  ('waste time watching film', 9628),
#  ('waste time watch movie', 9627),
#  ('waste time waste money', 9626),
#  ('waste time ve seen', 9625),
#  ('waste time unless want', 9624),
#  ('waste time unless like', 9623),
#  ('waste time talented cast', 9622),
#  ('waste time storyline terrible', 9621),
#  ('waste time spent watching', 9620),
#  ('waste time redeeming qualities', 9619),
#  ('waste time recommend movie', 9618),
#  ('waste time really need', 9617),
#  ('waste time read book', 9616),
#  ('waste time movie worth', 9615),
#  ('waste time movie unless', 9614),
#  ('waste time movie isn', 9613),
#  ('waste time money watching', 9612),
#  ('waste time money unless', 9611),
#  ('waste time money seeing', 9610),
#  ('waste time money score', 9609),
#  ('waste time money producers', 9608),
#  ('waste time money piece', 9607),
#  ('waste time money movie', 9606),
#  ('waste time money hope', 9605),
#  ('waste time money far', 9604),
#  ('waste time money energy', 9603),
#  ('waste time money effort', 9602),
#  ('waste time money don', 9601),
#  ('waste time money didn', 9600),
#  ('waste time money br', 9599),
#  ('waste time money boring', 9598),
#  ('waste time money bad', 9597),
#  ('waste time money actors', 9596),
#  ('waste time ll regret', 9595),
#  ('waste time like did', 9594),
#  ('waste time drivel br', 9593),
#  ('waste time don bother', 9592),
#  ('waste time br br', 9591),
#  ('waste time bad acting', 9590),
#  ('waste money waste time', 9589),
#  ('waste money time spend', 9588),
#  ('waste money br br', 9587),
#  ('waste hours life watching', 9586),
#  ('waste hour minutes life', 9585),
#  ('waste hard earned money', 9584),
#  ('waste film don waste', 9583),
#  ('waste film br br', 9582),
#  ('waste celluloid br br', 9581),
#  ('waste 90 minutes life', 9580),
#  ('wasn worst movie seen', 9579),
#  ('wasn scary br br', 9578),
#  ('wasn nominated best director', 9577),
#  ('wasn good br br', 9576),
#  ('wasn funny br br', 9575),
#  ('wasn expecting citizen kane', 9574),
#  ('wasn disappointed br br', 9573),
#  ('wasn compares writing styles', 9572),
#  ('wasn case watching dodgy', 9571),
#  ('wasn br br opinion', 9570),
#  ('wasn br br movie', 9569),
#  ('wasn bad wasn good', 9568),
#  ('wasn bad br br', 9567),
#  ('warning spoilers br br', 9566),
#  ('warning spoilers ahead br', 9565),
#  ('warning contains spoilers br', 9564),
#  ('warning contain spoilers br', 9563),
#  ('warning advise seen film', 9562),
#  ('war ii br br', 9561),
#  ('war effort br br', 9560),
#  ('wanted slap br br', 9559),
#  ('wanted money br br', 9558),
#  ('wanted like really did', 9557),
#  ('wanted like movie just', 9556),
#  ('want watch good movie', 9555),
#  ('want watch br br', 9554),
#  ('want vomit br br', 9553),
#  ('want movie makes think', 9552),
#  ('want movie br br', 9551),
#  ('want miss br br', 9550),
#  ('want live br br', 9549),
#  ('want leave 10 minutes', 9548),
#  ('want learn edit awfully', 9547),
#  ('want know br br', 9546),
#  ('want good horror movie', 9545),
#  ('want film br br', 9544),
#  ('want die br br', 9543),
#  ('want br br movie', 9542),
#  ('want br br just', 9541),
#  ('want br br interesting', 9540),
#  ('wanna throw eggs person', 9539),
#  ('wanna movie br br', 9538),
#  ('wan su li zhen', 9537),
#  ('walter matthau george burns', 9536),
#  ('wallace gromit curse rabbit', 9535),
#  ('walking stick br br', 9534),
#  ('walking desert travels heat', 9533),
#  ('wait wait wait wait', 9532),
#  ('vote seven br br', 9531),
#  ('vote br br title', 9530),
#  ('vote awful br br', 9529),
#  ('von galitzien http ferdinandvongalitzien', 9528),
#  ('volume br br grade', 9527),
#  ('voice overs br br', 9526),
#  ('voice actors really good', 9525),
#  ('vivian leigh clark gable', 9524),
#  ('visual style br br', 9523),
#  ('visiting extended family coming', 9522),
#  ('visit br br course', 9521),
#  ('visions god cultivated distinguished', 9520),
#  ('violent people getting blown', 9519),
#  ('violent convolutions second film', 9518),
#  ('violence youth beauty juvenile', 9517),
#  ('violence yes sex nudity', 9516),
#  ('violence gore br br', 9515),
#  ('violence br br film', 9514),
#  ('vinci code br br', 9513),
#  ('viewing experience br br', 9512),
#  ('viewer peeking corner coming', 9511),
#  ('viewer br br film', 9510),
#  ('view film br br', 9509),
#  ('view br br love', 9508),
#  ('view br br 10', 9507),
#  ('video store br br', 9506),
#  ('video game br br', 9505),
#  ('video dvd br br', 9504),
#  ('video camera br br', 9503),
#  ('vice versa br br', 9502),
#  ('vice locked room key', 9501),
#  ('version goodbye mr chips', 9500),
#  ('versailles saint quentin en', 9499),
#  ('ventures world english landowners', 9498),
#  ('velva breath suggest best', 9497),
#  ('vehicles just tepid remakes', 9496),
#  ('vehicles isn impress br', 9495),
#  ('vehicle ultra left wing', 9494),
#  ('vegetables known snozzcumbers giant', 9493),
#  ('vegas midler performing live', 9492),
#  ('vegas live concert special', 9491),
#  ('veadov offers film better', 9490),
#  ('ve written year old', 9489),
#  ('ve wine bottle cracked', 9488),
#  ('ve watching exact years', 9487),
#  ('ve watched tv shows', 9486),
#  ('ve watched past months', 9485),
#  ('ve watched movie twice', 9484),
#  ('ve watched movie times', 9483),
#  ('ve watched long time', 9482),
#  ('ve watched film times', 9481),
#  ('ve watched dvd times', 9480),
#  ('ve watched br br', 9479),
#  ('ve watched beginning end', 9478),
#  ('ve watch br br', 9477),
#  ('ve wasted hour half', 9476),
#  ('ve warned br br', 9475),
#  ('ve walked years pola', 9474),
#  ('ve waited years watch', 9473),
#  ('ve using imdb years', 9472),
#  ('ve used lot work', 9471),
#  ('ve understood work attracts', 9470),
#  ('ve spent time money', 9469),
#  ('ve seen worse movies', 9468),
#  ('ve seen worse movie', 9467),
#  ('ve seen worse films', 9466),
#  ('ve seen worse br', 9465),
#  ('ve seen ve seen', 9464),
#  ('ve seen ve got', 9463),
#  ('ve seen thousand times', 9462),
#  ('ve seen think ve', 9461),
#  ('ve seen recent years', 9460),
#  ('ve seen really bad', 9459),
#  ('ve seen quite time', 9458),
#  ('ve seen quite movies', 9457),
#  ('ve seen quite br', 9456),
#  ('ve seen past year', 9455),
#  ('ve seen movies plot', 9454),
#  ('ve seen movies like', 9453),
#  ('ve seen movie twice', 9452),
#  ('ve seen movie times', 9451),
#  ('ve seen movie time', 9450),
#  ('ve seen movie like', 9449),
#  ('ve seen million times', 9448),
#  ('ve seen low budget', 9447),
#  ('ve seen lot worse', 9446),
#  ('ve seen lot movies', 9445),
#  ('ve seen lot films', 9444),
#  ('ve seen lot better', 9443),
#  ('ve seen lot bad', 9442),
#  ('ve seen long time', 9441),
#  ('ve seen long long', 9440),
#  ('ve seen hundreds times', 9439),
#  ('ve seen horror movie', 9438),
#  ('ve seen horror film', 9437),
#  ('ve seen home movies', 9436),
#  ('ve seen half dozen', 9435),
#  ('ve seen film times', 9434),
#  ('ve seen film br', 9433),
#  ('ve seen far worse', 9432),
#  ('ve seen episode conclusion', 9431),
#  ('ve seen entire life', 9430),
#  ('ve seen countless times', 9429),
#  ('ve seen comes close', 9428),
#  ('ve seen br br', 9427),
#  ('ve seen better stuff', 9426),
#  ('ve seen better br', 9425),
#  ('ve seen better acting', 9424),
#  ('ve seen bad movies', 9423),
#  ('ve seen bad acting', 9422),
#  ('ve seen 10 times', 9421),
#  ('ve read comments film', 9420),
#  ('ve read br br', 9419),
#  ('ve just seen movie', 9418),
#  ('ve just seen film', 9417),
#  ('ve just seen br', 9416),
#  ('ve just finished watching', 9415),
#  ('ve heard lot people', 9414),
#  ('ve heard br br', 9413),
#  ('ve got br br', 9412),
#  ('ve experienced br br', 9411),
#  ('ve definitely seen worse', 9410),
#  ('ve certainly seen lot', 9409),
#  ('ve cared brad pitt', 9408),
#  ('ve br br movie', 9407),
#  ('ve br br don', 9406),
#  ('ve better br br', 9405),
#  ('ve attractive don intelligent', 9404),
#  ('ve actually come asylum', 9403),
#  ('vcr better suggest watching', 9402),
#  ('vastly superior br br', 9401),
#  ('various cigarette debris plethora', 9400),
#  ('variety solely cooking great', 9399),
#  ('vancouver international film festival', 9398),
#  ('van dien erika eleniak', 9397),
#  ('van damme br br', 9396),
#  ('vampire lestat queen damned', 9395),
#  ('validity record questionable just', 9394),
#  ('utterly terrible br br', 9393),
#  ('usual br br movie', 9392),
#  ('useful studios important training', 9391),
#  ('used try make sense', 9390),
#  ('use fast forward button', 9389),
#  ('urban legends final cut', 9388),
#  ('ups lies convincing documentary', 9387),
#  ('upper middle class family', 9386),
#  ('unwashed people suggest turn', 9385),
#  ('untimely death br br', 9384),
#  ('unmedicated state blown schizophrenia', 9383),
#  ('unless die hard fan', 9382),
#  ('unkempt stink ladened heroes', 9381),
#  ('university versailles saint quentin', 9380),
#  ('university paris pantheon sorbonne', 9379),
#  ('university paris dauphine university', 9378),
#  ('united states br br', 9377),
#  ('unintentional laughs br br', 9376),
#  ('understand initial curiosity seeing', 9375),
#  ('understand br br good', 9374),
#  ('uncle john br br', 9373),
#  ('uncle jesse john stamos', 9372),
#  ('uncle buck great outdoors', 9371),
#  ('uncle br br course', 9370),
#  ('uncle ben lewis black', 9369),
#  ('uncertainties times underscores historic', 9368),
#  ('uncertain believe searches happiness', 9367),
#  ('unceremoniously sent packing local', 9366),
#  ('uncanny ability retrieve various', 9365),
#  ('ugh did thibault mean', 9364),
#  ('ubiquitous ms banks laughing', 9363),
#  ('ua dw br br', 9362),
#  ('tyrone power henry fonda', 9361),
#  ('tyrone power died making', 9360),
#  ('tyrannus gladiator brought dead', 9359),
#  ('tyra rest modeling world', 9358),
#  ('tyra crew br br', 9357),
#  ('tyra consistent plugs camera', 9356),
#  ('tyra banks series goes', 9355),
#  ('typical women prison movie', 9354),
#  ('typical perfect crime thriller', 9353),
#  ('typical low budget horror', 9352),
#  ('type rescue scarlett miniseries', 9351),
#  ('type movie br br', 9350),
#  ('type film br br', 9349),
#  ('type character br br', 9348),
#  ('twist ending br br', 9347),
#  ('twist end br br', 9346),
#  ('twin peaks br br', 9345),
#  ('twilight zone outer limits', 9344),
#  ('twilight zone br br', 9343),
#  ('tv shows br br', 9342),
#  ('tv series homicide life', 9341),
#  ('tv series br br', 9340),
#  ('tv movies br br', 9339),
#  ('tv movie br br', 9338),
#  ('tv just trip local', 9337),
#  ('tv episode br br', 9336),
#  ('tv br br don', 9335),
#  ('tv audience br br', 9334),
#  ('turturro tim blake nelson', 9333),
#  ('turning grave br br', 9332),
#  ('turner classic movies night', 9331),
#  ('turned story sequel rape', 9330),
#  ('turned reached half hate', 9329),
#  ('turn worse br br', 9328),
#  ('turn tv just trip', 9327),
#  ('turn stomach br br', 9326),
#  ('turn coming mile away', 9325),
#  ('tunes golden collection volume', 9324),
#  ('tuned channel time assure', 9323),
#  ('trying make look like', 9322),
#  ('trying make ends meet', 9321),
#  ('trying create good writing', 9320),
#  ('trying create characters scrubs', 9319),
#  ('trying cleverly funny like', 9318),
#  ('trying cheat stabbed cuckolded', 9317),
#  ('trying characters alluding varied', 9316),
#  ('try escape fail injured', 9315),
#  ('try escape fail hurt', 9314),
#  ('try escape br br', 9313),
#  ('try don think disappointed', 9312),
#  ('try cure bad case', 9311),
#  ('truth justice american way', 9310),
#  ('trust br br 10', 9309),
#  ('truly worst films seen', 9308),
#  ('truly bad br br', 9307),
#  ('truly awful br br', 9306),
#  ('truly appreciate br br', 9305),
#  ('truly amazed prior reviewers', 9304),
#  ('true story jesse james', 9303),
#  ('true story christopher boyce', 9302),
#  ('true story br br', 9301),
#  ('true quality remains good', 9300),
#  ('true love br br', 9299),
#  ('true identity br br', 9298),
#  ('true heart bear noble', 9297),
#  ('true habitat homeless people', 9296),
#  ('true br br way', 9295),
#  ('true br br 10', 9294),
#  ('trip local bus station', 9293),
#  ('tribe leaves island unceremoniously', 9292),
#  ('trey sellars eddie murphy', 9291),
#  ('trey parker matt stone', 9290),
#  ('tremendous ballads bette midler', 9289),
#  ('trek series br br', 9288),
#  ('trek perilous wolves crazy', 9287),
#  ('treat watch br br', 9286),
#  ('travels heat sun people', 9285),
#  ('trash life br br', 9284),
#  ('tramp ii scamp adventure', 9283),
#  ('traits formed original novel', 9282),
#  ('traits formed margaret mitchell', 9281),
#  ('training grounds new burgeoning', 9280),
#  ('train wreck br br', 9279),
#  ('tragic ending br br', 9278),
#  ('tragic end br br', 9277),
#  ('tragic consequences br br', 9276),
#  ('tracks speeches radio interviews', 9275),
#  ('tracks best performance excellent', 9274),
#  ('trackers journeymen hell rests', 9273),
#  ('track times ve watched', 9272),
#  ('track terrible jokes movie', 9271),
#  ('town hopes finding gold', 9270),
#  ('town br br movie', 9269),
#  ('town ballyhara scarlett ventures', 9268),
#  ('tower hamlets health care', 9267),
#  ('towel took ludicrous story', 9266),
#  ('towel just shy 90', 9265),
#  ('touted award winning brit', 9264),
#  ('tous risques big risk', 9263),
#  ('tourists simply reason bother', 9262),
#  ('tourist trap genuinely spooky', 9261),
#  ('tourist trap definitely best', 9260),
#  ('totally surprised mrs forlani', 9259),
#  ('total waste time money', 9258),
#  ('total waste time br', 9257),
#  ('total recall starship troopers', 9256),
#  ('total absolute waste time', 9255),
#  ('toronto international film festival', 9254),
#  ('topnotch short story novel', 9253),
#  ('topless br br grade', 9252),
#  ('took place years ago', 9251),
#  ('took place br br', 9250),
#  ('tony randall jack klugman', 9249),
#  ('tony leung maggie cheung', 9248),
#  ('tony leung ka fai', 9247),
#  ('tony hawk pro skater', 9246),
#  ('tony curtis rock hudson', 9245),
#  ('tongue planted firmly cheek', 9244),
#  ('tone film br br', 9243),
#  ('tom hanks meg ryan', 9242),
#  ('tom arnold johnny depp', 9241),
#  ('today variety solely cooking', 9240),
#  ('today standards br br', 9239),
#  ('today reel short subjects', 9238),
#  ('today films br br', 9237),
#  ('today br br movie', 9236),
#  ('today br br film', 9235),
#  ('today 25 years ago', 9234),
#  ('tobel william post jr', 9233),
#  ('title role br br', 9232),
#  ('title film br br', 9231),
#  ('title br br film', 9230),
#  ('tinker tailor soldier spy', 9229),
#  ('timothy hutton sean penn', 9228),
#  ('timothy dalton zelah clarke', 9227),
#  ('times worse br br', 9226),
#  ('times br br yes', 9225),
#  ('times br br plot', 9224),
#  ('times br br movie', 9223),
#  ('times br br actors', 9222),
#  ('times br br 10', 9221),
#  ('times better br br', 9220),
#  ('time went br br', 9219),
#  ('time watching br br', 9218),
#  ('time ve seen movie', 9217),
#  ('time totally surprised mrs', 9216),
#  ('time time eventually agrees', 9215),
#  ('time time br br', 9214),
#  ('time tell br br', 9213),
#  ('time story takes place', 9212),
#  ('time spent watching movie', 9211),
#  ('time sense simultaneous beauty', 9210),
#  ('time seen horrible film', 9209),
#  ('time second time watched', 9208),
#  ('time screen br br', 9207),
#  ('time scene lady playing', 9206),
#  ('time saw years ago', 9205),
#  ('time saw second viewing', 9204),
#  ('time round br br', 9203),
#  ('time place br br', 9202),
#  ('time periods br br', 9201),
#  ('time period br br', 9200),
#  ('time movie br br', 9199),
#  ('time money br br', 9198),
#  ('time long time ago', 9197),
#  ('time line universe order', 9196),
#  ('time line br br', 9195),
#  ('time line altered cole', 9194),
#  ('time limits things did', 9193),
#  ('time limit just entire', 9192),
#  ('time like fluid finds', 9191),
#  ('time life ice did', 9190),
#  ('time life br br', 9189),
#  ('time late night tv', 9188),
#  ('time kitchen means time', 9187),
#  ('time haven seen movie', 9186),
#  ('time film br br', 9185),
#  ('time family haven tuned', 9184),
#  ('time eventually agrees marry', 9183),
#  ('time drivel br br', 9182),
#  ('time come br br', 9181),
#  ('time br br yes', 9180),
#  ('time br br watch', 9179),
#  ('time br br ve', 9178),
#  ('time br br understand', 9177),
#  ('time br br thought', 9176),
#  ('time br br think', 9175),
#  ('time br br story', 9174),
#  ('time br br seriously', 9173),
#  ('time br br say', 9172),
#  ('time br br reason', 9171),
#  ('time br br really', 9170),
#  ('time br br read', 9169),
#  ('time br br plot', 9168),
#  ('time br br overall', 9167),
#  ('time br br oh', 9166),
#  ('time br br mr', 9165),
#  ('time br br movie', 9164),
#  ('time br br like', 9163),
#  ('time br br let', 9162),
#  ('time br br know', 9161),
#  ('time br br just', 9160),
#  ('time br br john', 9159),
#  ('time br br isn', 9158),
#  ('time br br idea', 9157),
#  ('time br br great', 9156),
#  ('time br br good', 9155),
#  ('time br br final', 9154),
#  ('time br br films', 9153),
#  ('time br br film', 9152),
#  ('time br br fact', 9151),
#  ('time br br don', 9150),
#  ('time br br director', 9149),
#  ('time br br big', 9148),
#  ('time br br best', 9147),
#  ('time br br acting', 9146),
#  ('time br br 10', 9145),
#  ('time better spent watching', 9144),
#  ('time bad acting bad', 9143),
#  ('time avoid like plague', 9142),
#  ('time assure won disappointed', 9141),
#  ('tim meadows leon phelps', 9140),
#  ('till end br br', 9139),
#  ('ties murders cold blood', 9138),
#  ('thrown jail blamed murder', 9137),
#  ('thrown good measure film', 9136),
#  ('throw eggs person directed', 9135),
#  ('throw big fit 2000', 9134),
#  ('thriller br br 10', 9133),
#  ('thriller appropriate description think', 9132),
#  ('thrill ride br br', 9131),
#  ('threw towel took ludicrous', 9130),
#  ('threw towel just shy', 9129),
#  ('thoughts flick hope advice', 9128),
#  ('thought provoking br br', 9127),
#  ('thought pretty good movie', 9126),
#  ('thought possible br br', 9125),
#  ('thought movie pretty good', 9124),
#  ('thought movie br br', 9123),
#  ('thought great br br', 9122),
#  ('thought br br movie', 9121),
#  ('thought br br film', 9120),
#  ('thomas howell recall seeing', 9119),
#  ('thomas howell appeared movies', 9118),
#  ('thirty years br br', 9117),
#  ('thirty years ago br', 9116),
#  ('thinking br br movie', 9115),
#  ('think watching unkempt stink', 9114),
#  ('think watching paint dry', 9113),
#  ('think ve seen movie', 9112),
#  ('think ve seen episode', 9111),
#  ('think really bad movie', 9110),
#  ('think like br br', 9109),
#  ('think good thing movie', 9108),
#  ('think funny br br', 9107),
#  ('think did great job', 9106),
#  ('think did good job', 9105),
#  ('think br br story', 9104),
#  ('think br br really', 9103),
#  ('think br br movie', 9102),
#  ('think br br film', 9101),
#  ('things wrong movie br', 9100),
#  ('things wrong br br', 9099),
#  ('things worse br br', 9098),
#  ('things ve seen years', 9097),
#  ('things ve seen maybe', 9096),
#  ('things say movie br', 9095),
#  ('things say br br', 9094),
#  ('things right br br', 9093),
#  ('things movie br br', 9092),
#  ('things merge river runs', 9091),
#  ('things make life worthwhile', 9090),
#  ('things like br br', 9089),
#  ('things humorous br br', 9088),
#  ('things hill middle film', 9087),
#  ('things happening br br', 9086),
#  ('things happen don fact', 9085),
#  ('things hand br br', 9084),
#  ('things good people good', 9083),
#  ('things good br br', 9082),
#  ('things going br br', 9081),
#  ('things don make sense', 9080),
#  ('things don according plan', 9079),
#  ('things didn make sense', 9078),
#  ('things did golly ll', 9077),
#  ('things br br movie', 9076),
#  ('things br br film', 9075),
#  ('things br br end', 9074),
#  ('thing worth watching movie', 9073),
#  ('thing movie br br', 9072),
#  ('thing carlos mencia comedy', 9071),
#  ('thing br br want', 9070),
#  ('thing br br plot', 9069),
#  ('thing br br movie', 9068),
#  ('thing br br like', 9067),
#  ('thing br br film', 9066),
#  ('thing br br don', 9065),
#  ('thing br br acting', 9064),
#  ('theme song br br', 9063),
#  ('theme song addition ideally', 9062),
#  ('theme audience invited play', 9061),
#  ('theatrical trailer br br', 9060),
#  ('theatre thinking eh okay', 9059),
#  ('theater br br film', 9058),
#  ('thats sure br br', 9057),
#  ('thanks reading br br', 9056),
#  ('thank later br br', 9055),
#  ('thank goodness br br', 9054),
#  ('thank god br br', 9053),
#  ('texas chainsaw massacre 1974', 9052),
#  ('texas chain saw massacre', 9051),
#  ('test time br br', 9050),
#  ('terrorist group called werewolves', 9049),
#  ('terrible script br br', 9048),
#  ('terrible movie br br', 9047),
#  ('terrible film br br', 9046),
#  ('terrible fate br br', 9045),
#  ('terrible acting terrible script', 9044),
#  ('terrible acting br br', 9043),
#  ('terms budget schedule capable', 9042),
#  ('tends alternate bland puppetry', 9041),
#  ('tendencies definitely people nature', 9040),
#  ('tend just edge comes', 9039),
#  ('temporarily leave german count', 9038),
#  ('telling story br br', 9037),
#  ('tell story br br', 9036),
#  ('television series br br', 9035),
#  ('telemovie endearing spots fans', 9034),
#  ('teeth taken care instead', 9033),
#  ('teeth pulled instead unfortunately', 9032),
#  ('teeth killer snowman costume', 9031),
#  ('teeters uncertainties times underscores', 9030),
#  ('teens stay clear unless', 9029),
#  ('teens sad parents won', 9028),
#  ('teenage mutant ninja turtles', 9027),
#  ('tears eyes br br', 9026),
#  ('team br br just', 9025),
#  ('taylor aka gft amazon', 9024),
#  ('taste mouth br br', 9023),
#  ('tarzan ape man 1932', 9022),
#  ('target audience br br', 9021),
#  ('talents camera dynamics creating', 9020),
#  ('talbot lon chaney jr', 9019),
#  ('taking seriously br br', 9018),
#  ('takes turn worse br', 9017),
#  ('takes place single location', 9016),
#  ('takes place post apocalyptic', 9015),
#  ('takes place new york', 9014),
#  ('takes place br br', 9013),
#  ('takes cake br br', 9012),
#  ('takes breath away br', 9011),
#  ('taken seriously br br', 9010),
#  ('tag team table match', 9009),
#  ('table talking br br', 9008),
#  ('swing high swing low', 9007),
#  ('swat fly smack mosquito', 9006),
#  ('suspension disbelief br br', 9005),
#  ('suspend disbelief bushy eating', 9004),
#  ('susan sarandon natalie portman', 9003),
#  ('survivor week member tribe', 9002),
#  ('survive br br film', 9001),
#  ('surprisingly good br br', 9000),
#  ...]

# %% [markdown]
# #### NOTE
#
# * The value of a key is the word's position in the list of selected words within the `max_threshold` by CountVectorizer, and not the number of times it occurs.

# %% [markdown]
# ### Transform

# %%
X_train = cv.transform(df_train['text'])

# %%
X_train[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'int64'
# 	with 0 stored elements and shape (1, 10000)>

# %%
X_train[0].todense()
# Out:
# matrix([[0, 0, 0, ..., 0, 0, 0]])

# %%
X_train[0].todense()[0]
# Out:
# matrix([[0, 0, 0, ..., 0, 0, 0]])

# %%
np.unique(X_train[0].todense(), return_counts=True)
# Out:
# (matrix([[0, 0, 0, ..., 0, 0, 0]]), array([0, 0, 0, ..., 1, 1, 1]))

# %%
np.nonzero(X_train[0].todense())
# first array: row index; # second array: column index
# Out:
# (array([], dtype=int64), array([], dtype=int64))

# %%
# number of words
np.nonzero(X_train[0].todense())[0].size
# Out:
# 0

# %%
cv.inverse_transform(X_train[0])
# Out:
# [array([], dtype='<U291')]

# %%
# Test
X_test = cv.transform(df_test['text'])
X_test[0].todense()
# Out:
# matrix([[0, 0, 0, ..., 0, 0, 0]])

# %%
# ValidationY
X_val = cv.transform(df_val['text'])
X_val[0].todense()
# Out:
# matrix([[0, 0, 0, ..., 0, 0, 0]])

# %%
type(X_train)
# Out:
# scipy.sparse._csr.csr_matrix

# %% [markdown]
# # torch Dataset and Dataloader

# %%
from local_dataset_utilities import IMDBDataset

# %% [markdown]
# #### Train dataset

# %%
train_dataset = IMDBDataset(X_train.todense(), df_train['label'].to_numpy())

# %% [markdown]
# #### Test dataset

# %%
test_dataset = IMDBDataset(X_test.todense(), df_test['label'].to_numpy())

# %% [markdown]
# #### Validation dataset

# %%
val_dataset = IMDBDataset(X_val.todense(), df_val['label'].to_numpy())

# %% [markdown]
# ### Dataloaders

# %% [markdown]
# #### Batch size

# %%
batch_size = 32

# %%
train_dataloader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ##### Testing

# %%
for test_features, test_labels in train_dataloader:
    break

# %%
test_features.shape
# Out:
# torch.Size([32, 10000])

# %%
test_labels.shape
# Out:
# torch.Size([32])

# %%
test_dataloader = DataLoader(test_dataset, batch_size=batch_size, shuffle=False)

# %%
val_dataloader = DataLoader(val_dataset, batch_size=batch_size, shuffle=False)

# %% [markdown]
# # Model definitions

# %% [markdown]
# ## Pytorch model

# %%
from pytorch_model import PytorchLogReg

# %%
logreg_model = PytorchLogReg(num_features=max_input_features, num_classes=2)

# %% [markdown]
# ## Lightning model

# %%
from pytorch_model import LightningModel

# %%
learning_rate = 0.01

# %%
Logreg_L_Model = LightningModel(pytorch_model=logreg_model, learning_rate=learning_rate)

# %% [markdown]
# ## Callbacks

# %% [markdown]
# ### Model checkpoint

# %%
from lightning.pytorch.callbacks import ModelCheckpoint

# %%
Path.cwd()
# Out:
# PosixPath('/media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/SentimentAnalysis')

# %%
modelcheckpoints_dir = Path.cwd().joinpath("model_checkpoints")

# %%
if not modelcheckpoints_dir.exists():
    modelcheckpoints_dir.mkdir()

# %% [markdown]
# #### Set model checkpoint folder

# %%
import ipynbname

# %%
ipynbname.name()
# Out:
# 'SA_LogReg_v1'

# %%
model_checkpoint_folder = modelcheckpoints_dir.joinpath(f"{ipynbname.name()}")
model_checkpoint_folder
# Out:
# PosixPath('/media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/SentimentAnalysis/model_checkpoints/SA_LogReg_v1')

# %%
if not model_checkpoint_folder.exists():
    model_checkpoint_folder.mkdir()

# %%
model_checkpoint = ModelCheckpoint(dirpath=model_checkpoint_folder,
                                  filename="{epoch}-{val_acc:.2f}",
                                  save_top_k=1,
                                  save_last=True,
                                  monitor="val_acc",
                                  mode="max"
                                  )

# %%
callbacks = [model_checkpoint]

# %% [markdown]
# ### ProgressBar

# %%
from pytorch_model import MyProgressBar

# %%
callbacks.append(MyProgressBar())

# %%
callbacks
# Out:
# [<lightning.pytorch.callbacks.model_checkpoint.ModelCheckpoint at 0x7f5582ca5950>,
#  <pytorch_model.MyProgressBar at 0x7f5582ca7790>]

# %% [markdown]
# # Model Training

# %% [markdown]
# ## Logger

# %%
from lightning.pytorch.loggers import CSVLogger

# %%
logs_dir = Path.cwd().joinpath("logs")

# %%
if not logs_dir.exists():
    logs_dir.mkdir()

# %%
logging_folder = logs_dir.joinpath(ipynbname.name())

# %%
if not logging_folder.exists():
    logging_folder.mkdir()

# %% [markdown]
# ## Lightning Trainer

# %%
from lightning import Trainer

# %%
max_epochs = 20

# %% [markdown]
# ### Quick bug test

# %%
trainer = Trainer(logger=CSVLogger(save_dir=logging_folder, name="bow_model_v0"),
                 callbacks=callbacks,
                 accelerator="cpu",
                  devices="auto",
                 deterministic=True,
                 max_epochs=max_epochs,
                 fast_dev_run=True # testing for any bugs
                 )
# Out:
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs
# Running in `fast_dev_run` mode: will run the requested loop using 1 batch(es). Logging and checkpointing is suppressed.

# %%
trainer.fit(model=Logreg_L_Model, 
            train_dataloaders=train_dataloader, 
            val_dataloaders=val_dataloader
           )
# Out:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | PytorchLogReg      | 20.0 K | train
# 1 | train_acc | MulticlassAccuracy | 0      | train
# 2 | val_acc   | MulticlassAccuracy | 0      | train
# 3 | test_acc  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 20.0 K    Trainable params
# 0         Non-trainable params
# 20.0 K    Total params
# 0.080     Total estimated model params size (MB)
# 5         Modules in train mode
# 0         Modules in eval mode
# /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/.venv/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'train_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/.venv/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'val_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Epoch 0: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 41.74it/s]
# Epoch 0: 100%|█| 1/1 [00:00<00:00, 27.89it/s, val_loss=0.693, val_acc=0.469, tra
# `Trainer.fit` stopped: `max_steps=1` reached.
# Epoch 0: 100%|█| 1/1 [00:00<00:00, 26.60it/s, val_loss=0.693, val_acc=0.469, tra

# %% [markdown]
# ## Training

# %%
trainer = Trainer(logger=CSVLogger(save_dir=logging_folder, name="bow_model_v0"),
                 callbacks=callbacks,
                 accelerator="cpu",
                  devices="auto",
                 deterministic=True,
                 max_epochs=max_epochs,
                 fast_dev_run=False
                 )
# Out:
# Trainer already configured with model summary callbacks: [<class 'lightning.pytorch.callbacks.model_summary.ModelSummary'>]. Skipping setting a default `ModelSummary` callback.
# GPU available: False, used: False
# TPU available: False, using: 0 TPU cores
# HPU available: False, using: 0 HPUs

# %%
trainer.fit(model=Logreg_L_Model, 
            train_dataloaders=train_dataloader, 
            val_dataloaders=val_dataloader
           )
# Out:
#   | Name      | Type               | Params | Mode
# ---------------------------------------------------------
# 0 | model     | PytorchLogReg      | 20.0 K | train
# 1 | train_acc | MulticlassAccuracy | 0      | train
# 2 | val_acc   | MulticlassAccuracy | 0      | train
# 3 | test_acc  | MulticlassAccuracy | 0      | train
# ---------------------------------------------------------
# 20.0 K    Trainable params
# 0         Non-trainable params
# 20.0 K    Total params
# 0.080     Total estimated model params size (MB)
# 5         Modules in train mode
# 0         Modules in eval mode
# Epoch 0: 100%|████████████████████| 1094/1094 [00:06<00:00, 163.57it/s, v_num=0]
# Epoch 1: 100%|█| 1094/1094 [00:07<00:00, 151.08it/s, v_num=0, val_loss=0.693, va
# Epoch 2: 100%|█| 1094/1094 [00:07<00:00, 151.57it/s, v_num=0, val_loss=0.692, va
# Epoch 3: 100%|█| 1094/1094 [00:07<00:00, 145.69it/s, v_num=0, val_loss=0.692, va
# Epoch 4: 100%|█| 1094/1094 [00:07<00:00, 146.43it/s, v_num=0, val_loss=0.691, va
# Epoch 5: 100%|█| 1094/1094 [00:07<00:00, 139.83it/s, v_num=0, val_loss=0.691, va
# Epoch 6: 100%|█| 1094/1094 [00:07<00:00, 145.42it/s, v_num=0, val_loss=0.691, va
# Epoch 7: 100%|█| 1094/1094 [00:07<00:00, 145.10it/s, v_num=0, val_loss=0.690, va
# Epoch 8: 100%|█| 1094/1094 [00:07<00:00, 146.56it/s, v_num=0, val_loss=0.690, va
# Epoch 9: 100%|█| 1094/1094 [00:07<00:00, 138.27it/s, v_num=0, val_loss=0.689, va
# Epoch 10: 100%|█| 1094/1094 [00:07<00:00, 139.00it/s, v_num=0, val_loss=0.689, v
# Epoch 11: 100%|█| 1094/1094 [00:07<00:00, 145.56it/s, v_num=0, val_loss=0.689, v
# Epoch 12: 100%|█| 1094/1094 [00:08<00:00, 132.36it/s, v_num=0, val_loss=0.688, v
# Epoch 13: 100%|█| 1094/1094 [00:07<00:00, 152.13it/s, v_num=0, val_loss=0.688, v
# Epoch 14: 100%|█| 1094/1094 [00:07<00:00, 141.72it/s, v_num=0, val_loss=0.687, v
# Epoch 15: 100%|█| 1094/1094 [00:07<00:00, 143.69it/s, v_num=0, val_loss=0.687, v
# Epoch 16: 100%|█| 1094/1094 [00:07<00:00, 140.67it/s, v_num=0, val_loss=0.687, v
# Epoch 17: 100%|█| 1094/1094 [00:07<00:00, 147.65it/s, v_num=0, val_loss=0.686, v
# Epoch 18: 100%|█| 1094/1094 [00:07<00:00, 137.59it/s, v_num=0, val_loss=0.686, v
# Epoch 19: 100%|█| 1094/1094 [00:07<00:00, 148.70it/s, v_num=0, val_loss=0.686, v
# Epoch 19: 100%|█| 1094/1094 [00:07<00:00, 138.71it/s, v_num=0, val_loss=0.686, v
# `Trainer.fit` stopped: `max_epochs=20` reached.
# Epoch 19: 100%|█| 1094/1094 [00:07<00:00, 138.62it/s, v_num=0, val_loss=0.686, v

# %% [markdown]
# ### Test set evaluation

# %%
trainer.test(model=Logreg_L_Model, dataloaders=test_dataloader, ckpt_path="best")
# Out:
# Restoring states from the checkpoint path at /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/SentimentAnalysis/model_checkpoints/SA_LogReg_v1/epoch=17-val_acc=0.59.ckpt
# Loaded model weights from the checkpoint at /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/SentimentAnalysis/model_checkpoints/SA_LogReg_v1/epoch=17-val_acc=0.59.ckpt
# /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/.venv/lib/python3.11/site-packages/lightning/pytorch/trainer/connectors/data_connector.py:424: The 'test_dataloader' does not have many workers which may be a bottleneck. Consider increasing the value of the `num_workers` argument` to `num_workers=7` in the `DataLoader` to improve performance.
# Testing: |                                                | 0/? [00:00<?, ?it/s]────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.5907999873161316
#         test_loss           0.6859671473503113
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.6859671473503113, 'test_acc': 0.5907999873161316}]

# %%
trainer.test(model=Logreg_L_Model, dataloaders=test_dataloader, ckpt_path="last")
# Out:
# Restoring states from the checkpoint path at /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/SentimentAnalysis/model_checkpoints/SA_LogReg_v1/last.ckpt
# Loaded model weights from the checkpoint at /media/skesava/D/Training/MachineLearning/Pytorch/NLP_using_LLMs/SentimentAnalysis/model_checkpoints/SA_LogReg_v1/last.ckpt
# Testing: |                                                | 0/? [00:00<?, ?it/s]────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#         test_acc            0.5669999718666077
#         test_loss           0.6852495074272156
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# [{'test_loss': 0.6852495074272156, 'test_acc': 0.5669999718666077}]
